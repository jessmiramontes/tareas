# %% [markdown]
# ### Movie recommendation system
#
# Would we be able to predict which movies might or might not be a commercial success? This dataset collects part of the knowledge from the API TMDB, which contains only 5000 movies out of the total number. The following resources are available:
#
# tmdb_5000_movies:
# https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_movies.csv
#
#
# tmdb_5000_credits:
# https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_credits.csv

# %%
# Libraries
import pandas as pd
import pandasql as psql
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import accuracy_score
from sklearn.metrics.pairwise import cosine_similarity
from pickle import dump

# %%
# Load data
movies = pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_movies.csv')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 750.6+ KB

# %%
movies.sample(10)
# Out:
#         budget                                             genres  \
# 2207  20000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 2031  22000000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 852   70000000  [{"id": 53, "name": "Thriller"}, {"id": 18, "n...
# 2898  12000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 2770         0                      [{"id": 18, "name": "Drama"}]
# 3960         0  [{"id": 35, "name": "Comedy"}, {"id": 10751, "...
# 719   60000000  [{"id": 10402, "name": "Music"}, {"id": 99, "n...
# 3744   4500000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 3036  10000000  [{"id": 99, "name": "Documentary"}, {"id": 104...
# 878   90000000  [{"id": 10752, "name": "War"}, {"id": 18, "nam...
#
#                                                homepage      id  \
# 2207                     http://www.12rounds-movie.com/   17134
# 2031           http://theinformantmovie.warnerbros.com/   11323
# 852                                                 NaN    9833
# 2898               http://www.cityoflifeanddeath.co.uk/   21345
# 2770                                                NaN   13074
# 3960  https://www.facebook.com/pages/The-Deported/46...  170480
# 719                       http://www.thisisit-movie.com   13576
# 3744      https://www.facebook.com/HanselGretelGetBaked  165864
# 3036    http://www.1dthisisus-movie.com/feature/mosaic/  164558
# 878                                                 NaN    3683
#
#                                                keywords original_language  \
# 2207  [{"id": 6149, "name": "police"}, {"id": 8233, ...                en
# 2031  [{"id": 5888, "name": "agriculture"}, {"id": 6...                en
# 852   [{"id": 246, "name": "dancing"}, {"id": 1523, ...                en
# 2898  [{"id": 1327, "name": "war crimes"}, {"id": 15...                zh
# 2770                    [{"id": 6075, "name": "sport"}]                en
# 3960                                                 []                en
# 719   [{"id": 3490, "name": "pop star"}, {"id": 6027...                en
# 3744  [{"id": 616, "name": "witch"}, {"id": 10776, "...                en
# 3036                  [{"id": 6029, "name": "concert"}]                en
# 878   [{"id": 1956, "name": "world war ii"}, {"id": ...                en
#
#                     original_title  \
# 2207                     12 Rounds
# 2031                The Informant!
# 852       The Phantom of the Opera
# 2898                        南京!南京!
# 2770        Resurrecting the Champ
# 3960                  The Deported
# 719   Michael Jackson's This Is It
# 3744   Hansel and Gretel Get Baked
# 3036     One Direction: This Is Us
# 878           Flags of Our Fathers
#
#                                                overview  popularity  \
# 2207  When New Orleans cop Danny Fisher prevents a b...   15.661350
# 2031  A rising star at agri-industry giant Archer Da...   17.772518
# 852   Deformed since birth, a bitter man known only ...   18.927463
# 2898  City of Life and Death takes place in 1937, du...    4.793348
# 2770  Up-and-coming sports reporter rescues a homele...    4.898437
# 3960  An Italian-American actor is deported to Mexic...    0.194848
# 719   A compilation of interviews, rehearsals and ba...   15.798622
# 3744  An intense new marijuana strain named “Black F...    2.503612
# 3036  Go behind the scenes during One Directions sel...    7.944457
# 878   There were five Marines and one Navy Corpsman ...   23.936600
#
#                                    production_companies  \
# 2207  [{"name": "The Mark Gordon Company", "id": 155...
# 2031  [{"name": "Section Eight", "id": 129}, {"name"...
# 852   [{"name": "Odyssey Entertainment", "id": 3539}...
# 2898  [{"name": "Media Asia Films", "id": 5552}, {"n...
# 2770  [{"name": "Battleplan Productions", "id": 2108...
# 3960                                                 []
# 719            [{"name": "Columbia Pictures", "id": 5}]
# 3744     [{"name": "Tribeca Productions", "id": 11391}]
# 3036  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 878   [{"name": "DreamWorks SKG", "id": 27}, {"name"...
#
#                                    production_countries release_date  \
# 2207  [{"iso_3166_1": "US", "name": "United States o...   2009-03-19
# 2031  [{"iso_3166_1": "US", "name": "United States o...   2009-09-18
# 852   [{"iso_3166_1": "GB", "name": "United Kingdom"...   2004-12-08
# 2898  [{"iso_3166_1": "CN", "name": "China"}, {"iso_...   2009-04-22
# 2770  [{"iso_3166_1": "US", "name": "United States o...   2007-06-14
# 3960                                                 []   2010-06-15
# 719   [{"iso_3166_1": "US", "name": "United States o...   2009-10-28
# 3744  [{"iso_3166_1": "US", "name": "United States o...   2013-02-19
# 3036  [{"iso_3166_1": "US", "name": "United States o...   2013-08-28
# 878   [{"iso_3166_1": "US", "name": "United States o...   2006-10-18
#
#         revenue  runtime                                   spoken_languages  \
# 2207   17280326    108.0  [{"iso_639_1": "cs", "name": "\u010cesk\u00fd"...
# 2031   35424826    108.0           [{"iso_639_1": "en", "name": "English"}]
# 852   154648887    143.0  [{"iso_639_1": "it", "name": "Italiano"}, {"is...
# 2898   10652498    132.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 2770          0    112.0           [{"iso_639_1": "en", "name": "English"}]
# 3960          0     90.0           [{"iso_639_1": "en", "name": "English"}]
# 719           0    111.0           [{"iso_639_1": "en", "name": "English"}]
# 3744          0     86.0           [{"iso_639_1": "en", "name": "English"}]
# 3036          0     92.0  [{"iso_639_1": "pt", "name": "Portugu\u00eas"}...
# 878    65900249    132.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 2207  Released                                     Survive all 12
# 2031  Released                            Based on a tattle-tale.
# 852   Released  The classic musical comes to the big screen fo...
# 2898  Released                                                NaN
# 2770  Released                                                NaN
# 3960  Released                                                NaN
# 719   Released                  Like You've Never Seen Him Before
# 3744  Released                                                NaN
# 3036  Released                            A motion picture event.
# 878   Released  They fight for their country but they die for ...
#
#                             title  vote_average  vote_count
# 2207                    12 Rounds           5.7         220
# 2031               The Informant!           6.0         301
# 852      The Phantom of the Opera           7.0         438
# 2898       City of Life and Death           7.6          55
# 2770       Resurrecting the Champ           5.9          60
# 3960                 The Deported           0.0           0
# 719                    This Is It           6.7         247
# 3744  Hansel and Gretel Get Baked           4.8          67
# 3036    One Direction: This Is Us           8.0         201
# 878          Flags of Our Fathers           6.7         526

# %%
credits = pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/k-nearest-neighbors-project-tutorial/main/tmdb_5000_credits.csv')
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
credits.sample(10)
# Out:
#       movie_id                            title  \
# 2524     16769            Coal Miner's Daughter
# 1407     10066                     House of Wax
# 1292      1257                Because I Said So
# 743       6435                  Practical Magic
# 2068      2196               Death at a Funeral
# 753       5820                     The Sentinel
# 624      72331  Abraham Lincoln: Vampire Hunter
# 915       9441                          Stepmom
# 406      51052                 Arthur Christmas
# 2174     47941                Under the Rainbow
#
#                                                    cast  \
# 2524  [{"cast_id": 2, "character": "Loretta Lynn", "...
# 1407  [{"cast_id": 22, "character": "Carly Jones", "...
# 1292  [{"cast_id": 6, "character": "Daphne", "credit...
# 743   [{"cast_id": 1, "character": "Sally Owens", "c...
# 2068  [{"cast_id": 4, "character": "Daniel", "credit...
# 753   [{"cast_id": 1, "character": "Pete Garrison", ...
# 624   [{"cast_id": 8, "character": "Abraham Lincoln"...
# 915   [{"cast_id": 9, "character": "Isabel Kelly", "...
# 406   [{"cast_id": 2, "character": "Arthur (voice)",...
# 2174  [{"cast_id": 2, "character": "Bruce Thorpe", "...
#
#                                                    crew
# 2524  [{"credit_id": "589e87c7c3a3684bb7004dc7", "de...
# 1407  [{"credit_id": "52fe43199251416c750036c1", "de...
# 1292  [{"credit_id": "52fe42ebc3a36847f802cb51", "de...
# 743   [{"credit_id": "52fe4451c3a36847f808eeb7", "de...
# 2068  [{"credit_id": "52fe4340c3a36847f8045d0d", "de...
# 753   [{"credit_id": "556ae1fdc3a3682725000fe5", "de...
# 624   [{"credit_id": "52fe4864c3a368484e0f66a9", "de...
# 915   [{"credit_id": "594311409251417f77013a6c", "de...
# 406   [{"credit_id": "5913a131925141580d00132d", "de...
# 2174  [{"credit_id": "52fe474fc3a36847f812e93d", "de...

# %%
import sqlite3

conn = sqlite3.connect("../data/movies_database.db")

movies.to_sql("movies_table", conn, if_exists = "replace", index = False)
credits.to_sql("credits_table", conn, if_exists = "replace", index = False)
# Out:
# 4803

# %%
# Merge tables for creating a new DataFrame

query = """
    SELECT *
    FROM movies_table
    INNER JOIN credits_table
    ON movies_table.title = credits_table.title;
"""

total_data = pd.read_sql_query(query, conn)
conn.close()

total_data = total_data.loc[:, ~total_data.columns.duplicated()]
total_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
#  15  status                4809 non-null   object
#  16  tagline               3965 non-null   object
#  17  title                 4809 non-null   object
#  18  vote_average          4809 non-null   float64
#  19  vote_count            4809 non-null   int64
#  20  movie_id              4809 non-null   int64
#  21  cast                  4809 non-null   object
#  22  crew                  4809 non-null   object
# dtypes: float64(3), int64(5), object(15)
# memory usage: 864.2+ KB

# %%
total_data.sample(10)
# Out:
#          budget                                             genres  \
# 1235   40000000  [{"id": 80, "name": "Crime"}, {"id": 28, "name...
# 3265          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4606          0                [{"id": 99, "name": "Documentary"}]
# 2853   12000000  [{"id": 35, "name": "Comedy"}, {"id": 10751, "...
# 384    90000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 4314    1344000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 156   140000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 3996    2700000  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# 1663   30000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 1533   34000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                            homepage      id  \
# 1235                                           None   11398
# 3265                                           None  209263
# 4606         http://www.51birchstreet.com/index.php   79161
# 2853                                           None   34549
# 384                                            None    8358
# 4314                                           None   86331
# 156                                            None     616
# 3996                                           None   17264
# 1663              http://www.antitrustthemovie.com/    9989
# 1533  http://www.mgm.com/view/movie/1292/Moonraker/     698
#
#                                                keywords original_language  \
# 1235  [{"id": 478, "name": "china"}, {"id": 3292, "n...                en
# 3265  [{"id": 4501, "name": "masseuse"}, {"id": 4543...                en
# 4606                                                 []                en
# 2853                                                 []                en
# 384   [{"id": 911, "name": "exotic island"}, {"id": ...                en
# 4314  [{"id": 254, "name": "france"}, {"id": 293, "n...                fr
# 156   [{"id": 233, "name": "japan"}, {"id": 1327, "n...                en
# 3996  [{"id": 383, "name": "poker"}, {"id": 2673, "n...                en
# 1663  [{"id": 1576, "name": "technology"}, {"id": 21...                en
# 1533  [{"id": 110, "name": "venice"}, {"id": 1583, "...                en
#
#              original_title  \
# 1235         The Art of War
# 3265            Enough Said
# 4606        51 Birch Street
# 2853  Max Keeble's Big Move
# 384               Cast Away
# 4314                      Q
# 156        The Last Samurai
# 3996     The Black Stallion
# 1663              Antitrust
# 1533              Moonraker
#
#                                                overview  popularity  \
# 1235  When ruthless terrorists threaten to bring dow...    7.832337
# 3265  Eva is a divorced soon-to-be empty-nester wond...   14.969093
# 4606  Documentary filmmaker Doug Block had every rea...    0.049921
# 2853  Max Keeble, the victim of his 7th grade class,...    1.081822
# 384   Chuck, a top international manager for FedEx, ...   57.739713
# 4314  In a social context deteriorated by a countryw...   20.422246
# 156   Nathan Algren is an American hired to instruct...   52.341226
# 3996  While traveling with his father, young Alec be...   11.359720
# 1663  A computer programmer's dream job at a hot Por...    8.359599
# 1533  During the transportation of a Space Shuttle a...   29.887404
#
#                                    production_companies  ... runtime  \
# 1235  [{"name": "Amen Ra Films", "id": 421}, {"name"...  ...   117.0
# 3265   [{"name": "Fox Searchlight Pictures", "id": 43}]  ...    93.0
# 4606       [{"name": "Copacetic Pictures", "id": 8139}]  ...    90.0
# 2853  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...    86.0
# 384   [{"name": "DreamWorks SKG", "id": 27}, {"name"...  ...   143.0
# 4314  [{"name": "Acajou Films", "id": 18519}, {"name...  ...   103.0
# 156   [{"name": "Cruise/Wagner Productions", "id": 4...  ...   154.0
# 3996             [{"name": "United Artists", "id": 60}]  ...   118.0
# 1663  [{"name": "Industry Entertainment", "id": 376}...  ...   108.0
# 1533  [{"name": "United Artists", "id": 60}, {"name"...  ...   126.0
#
#                                        spoken_languages    status  \
# 1235           [{"iso_639_1": "en", "name": "English"}]  Released
# 3265           [{"iso_639_1": "en", "name": "English"}]  Released
# 4606                                                 []  Released
# 2853           [{"iso_639_1": "en", "name": "English"}]  Released
# 384   [{"iso_639_1": "ru", "name": "P\u0443\u0441\u0...  Released
# 4314     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"}]  Released
# 156   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 3996  [{"iso_639_1": "ar", "name": "\u0627\u0644\u06...  Released
# 1663           [{"iso_639_1": "en", "name": "English"}]  Released
# 1533  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                                                 tagline  \
# 1235                                   Who is your foe?
# 3265                                               None
# 4606           Do you really want to know your parents?
# 2853                              His World. His Rules.
# 384       At the edge of the world, his journey begins.
# 4314                                               None
# 156   In the face of an enemy, in the heart of one m...
# 3996  From the moment he first saw the stallion, he ...
# 1663      Truth can be dangerous...Trust can be deadly.
# 1533                    Outer space now belongs to 007.
#
#                       title vote_average vote_count movie_id  \
# 1235         The Art of War          5.6        135    11398
# 3265            Enough Said          6.6        348   209263
# 4606        51 Birch Street          6.8          6    79161
# 2853  Max Keeble's Big Move          5.4         33    34549
# 384               Cast Away          7.5       3218     8358
# 4314                 Desire          4.1        140    86331
# 156        The Last Samurai          7.3       1895      616
# 3996     The Black Stallion          7.0         59    17264
# 1663              Antitrust          5.8        153     9989
# 1533              Moonraker          5.9        541      698
#
#                                                    cast  \
# 1235  [{"cast_id": 9, "character": "Neil Shaw", "cre...
# 3265  [{"cast_id": 3, "character": "Eva", "credit_id...
# 4606  [{"cast_id": 1001, "character": "Herself", "cr...
# 2853  [{"cast_id": 1, "character": "Max Keeble", "cr...
# 384   [{"cast_id": 3, "character": "Chuck Noland", "...
# 4314  [{"cast_id": 1005, "character": "C\u00e9cile",...
# 156   [{"cast_id": 11, "character": "Captain Nathan ...
# 3996  [{"cast_id": 1, "character": "Alec Ramsey", "c...
# 1663  [{"cast_id": 18, "character": "Milo Hoffman", ...
# 1533  [{"cast_id": 15, "character": "James Bond", "c...
#
#                                                    crew
# 1235  [{"credit_id": "52fe44389251416c7502cfeb", "de...
# 3265  [{"credit_id": "52fe4d60c3a368484e1e5c23", "de...
# 4606  [{"credit_id": "52fe49c4c3a368484e13e9bb", "de...
# 2853  [{"credit_id": "52fe456a9251416c91031963", "de...
# 384   [{"credit_id": "52fe44a2c3a36847f80a1505", "de...
# 4314  [{"credit_id": "577ce3ba9251413b63001f8c", "de...
# 156   [{"credit_id": "52fe425ec3a36847f8018e53", "de...
# 3996  [{"credit_id": "54ee5070925141795f004b0c", "de...
# 1663  [{"credit_id": "52fe4558c3a36847f80c90af", "de...
# 1533  [{"credit_id": "52fe426cc3a36847f801d72b", "de...
#
# [10 rows x 23 columns]

# %%
# Create a dataframe only with selected columns
selected_columns = ["movie_id", "title", "overview", "genres", "keywords", "cast", "crew"]
df_selected = total_data[selected_columns]
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4809 non-null   int64
#  1   title     4809 non-null   object
#  2   overview  4806 non-null   object
#  3   genres    4809 non-null   object
#  4   keywords  4809 non-null   object
#  5   cast      4809 non-null   object
#  6   crew      4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 263.1+ KB

# %%
# Data transform as expected
import json

def load_json_safe(json_str, default_value = None):
    try:
        return json.loads(json_str)
    except (TypeError, json.JSONDecodeError):
        return default_value
    
df_selected["genres"] = df_selected["genres"].apply(lambda x: [item["name"] for item in json.loads(x)] if pd.notna(x) else None)
df_selected["keywords"] = df_selected["keywords"].apply(lambda x: [item["name"] for item in json.loads(x)] if pd.notna(x) else None)

df_selected["cast"] = df_selected["cast"].apply(lambda x: [item["name"] for item in json.loads(x)][:3] if pd.notna(x) else None)

df_selected["crew"] = df_selected["crew"].apply(lambda x: " ".join([crew_member['name'] for crew_member in load_json_safe(x) if crew_member['job'] == 'Director']))

df_selected["overview"] = df_selected["overview"].apply(lambda x: [x])

df_selected.head()
# Out:
# /tmp/ipykernel_3968/1375002452.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["genres"] = df_selected["genres"].apply(lambda x: [item["name"] for item in json.loads(x)] if pd.notna(x) else None)
# /tmp/ipykernel_3968/1375002452.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["keywords"] = df_selected["keywords"].apply(lambda x: [item["name"] for item in json.loads(x)] if pd.notna(x) else None)
# /tmp/ipykernel_3968/1375002452.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["cast"] = df_selected["cast"].apply(lambda x: [item["name"] for item in json.loads(x)][:3] if pd.notna(x) else None)
# /tmp/ipykernel_3968/1375002452.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["crew"] = df_selected["crew"].apply(lambda x: " ".join([crew_member['name'] for crew_member in load_json_safe(x) if crew_member['job'] == 'Director']))
# /tmp/ipykernel_3968/1375002452.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["overview"] = df_selected["overview"].apply(lambda x: [x])
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In the 22nd century, a paraplegic Marine is d...
# 1  [Captain Barbossa, long believed to be dead, h...
# 2  [A cryptic message from Bond’s past sends him ...
# 3  [Following the death of District Attorney Harv...
# 4  [John Carter is a war-weary, former military c...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                cast               crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      James Cameron
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     Gore Verbinski
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         Sam Mendes
# 3      [Christian Bale, Michael Caine, Gary Oldman]  Christopher Nolan
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     Andrew Stanton

# %%
df_selected["overview"] = df_selected["overview"].apply(lambda x: [str(x)])
df_selected["genres"] = df_selected["genres"].apply(lambda x: [str(genre) for genre in x])
df_selected["keywords"] = df_selected["keywords"].apply(lambda x: [str(keyword) for keyword in x])
df_selected["cast"] = df_selected["cast"].apply(lambda x: [str(actor) for actor in x])
df_selected["crew"] = df_selected["crew"].apply(lambda x: [str(crew_member) for crew_member in x])

df_selected["tags"] = df_selected["overview"] + df_selected["genres"] + df_selected["keywords"] + df_selected["cast"] + df_selected["crew"]
df_selected["tags"] = df_selected["tags"].apply(lambda x: ",".join(x).replace(",", " "))

df_selected.drop(columns = ["genres", "keywords", "cast", "crew", "overview"], inplace = True)

df_selected.iloc[0].tags
# Out:
# /tmp/ipykernel_3968/46640601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["overview"] = df_selected["overview"].apply(lambda x: [str(x)])
# /tmp/ipykernel_3968/46640601.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["genres"] = df_selected["genres"].apply(lambda x: [str(genre) for genre in x])
# /tmp/ipykernel_3968/46640601.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["keywords"] = df_selected["keywords"].apply(lambda x: [str(keyword) for keyword in x])
# /tmp/ipykernel_3968/46640601.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["cast"] = df_selected["cast"].apply(lambda x: [str(actor) for actor in x])
# /tmp/ipykernel_3968/46640601.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["crew"] = df_selected["crew"].apply(lambda x: [str(crew_member) for crew_member in x])
# /tmp/ipykernel_3968/46640601.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["tags"] = df_selected["overview"] + df_selected["genres"] + df_selected["keywords"] + df_selected["cast"] + df_selected["crew"]
# /tmp/ipykernel_3968/46640601.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["tags"] = df_selected["tags"].apply(lambda x: ",".join(x).replace(",", " "))
# /tmp/ipykernel_3968/46640601.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.drop(columns = ["genres", "keywords", "cast", "crew", "overview"], inplace = True)
# '["[\'In the 22nd century  a paraplegic Marine is dispatched to the moon Pandora on a unique mission  but becomes torn between following orders and protecting an alien civilization.\']"] Action Adventure Fantasy Science Fiction culture clash future space war space colony society space travel futuristic romance space alien tribe alien planet cgi marine soldier battle love affair anti war power relations mind and soul 3d Sam Worthington Zoe Saldana Sigourney Weaver J a m e s   C a m e r o n'

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df_selected["tags"])

model = NearestNeighbors(n_neighbors = 6, algorithm = "brute", metric = "cosine")
model.fit(tfidf_matrix)

def get_movie_recommendations(movie_title):
    movie_index = df_selected[df_selected["title"] == movie_title].index[0]
    distances, indices = model.kneighbors(tfidf_matrix[movie_index])
    similar_movies = [(df_selected["title"][i], distances[0][j]) for j, i in enumerate(indices[0])]
    return similar_movies[1:]

input_movie = "Practical Magic"
recommendations = get_movie_recommendations(input_movie)
print("Film recommendations '{}'".format(input_movie))
for movie, distance in recommendations:
    print("- Film: {}".format(movie))
# Out:
# Film recommendations 'Practical Magic'
# - Film: Into the Woods
# - Film: Harry Potter and the Order of the Phoenix
# - Film: ParaNorman
# - Film: Harry Potter and the Chamber of Secrets
# - Film: Hansel & Gretel: Witch Hunters

# %%
dump(model, open("../models/knn_neighbors-6_algorithm-brute_metric-cosine.sav", "wb"))
